# %%
import pyspark

import os

for dirname, _, filenames in os.walk('data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# data/citizens2.txt
# data/flemish_districs.txt
# data/zipcodes.csv
# data/citizens.txt
# data/stops.txt

# %%
file = open("data/citizens.txt", 'r')
for line in file:
    print(line)

file.close()
# Out:
# KONINKRIJK BELGIE - ROYAUME DE BELGIQUE
#
#
#
# BRUSSELS HOOFDSTEDELIJK GEWEST - REGION DE BRUXELLES-CAPITALE
#
#
#
# ARR. BRUSSEL HOOFDSTAD - ARR. DE BRUXELLES-CAPITALE
#
#
#
# Anderlecht 117.724
#
# Brussel / Bruxelles 177.112
#
# Elsene / Ixelles 86.336
#
# Etterbeek 47.410
#
# Evere 41.016
#
# Ganshoren 24.794
#
# Jette 52.144
#
# Koekelberg 21.765
#
# Oudergem / Auderghem 33.725
#
# Schaarbeek / Schaerbeek 132.097
#
# Sint‐Agatha‐Berchem / Berchem‐Sainte‐Agathe 24.831
#
# Sint‐Gillis / Saint‐Gilles 49.361
#
# Sint‐Jans‐Molenbeek / Molenbeek‐Saint‐Jean 95.455
#
# Sint‐Joost‐ten‐Node / Saint‐Josse‐ten‐Noode 26.813
#
# Sint‐Lambrechts‐Woluwe / Woluwe‐Saint‐Lambert 56.212
#
# Sint‐Pieters‐Woluwe / Woluwe‐Saint‐Pierre 41.513
#
# Ukkel / Uccle 82.038
#
# Vorst / Forest 55.694
#
# Watermaal‐Bosvoorde / Watermael‐Boitsfort 25.001
#
#
#
# VLAAMS GEWEST - REGION FLAMANDE
#
#
#
# PROVINCIE ANTWERPEN - PROVINCE D'ANVERS
#
#
#
# ARRONDISSEMENT ANTWERPEN - ARRONDISSEMENT D'ANVERS
#
#
#
# ...
